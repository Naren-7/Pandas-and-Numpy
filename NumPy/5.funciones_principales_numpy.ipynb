# %% [markdown]
# ### Importando librerías

# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 8,  7,  9,  6, 12],
#        [ 7, 17,  7,  3,  9]])

# %%
arr
# Out:
# array([ 8,  7,  9,  6, 12,  7, 17,  7,  3,  9])

# %% [markdown]
# ### Max

# %%
arr.max()
# Out:
# 17

# %%
matriz
# Out:
# array([[ 8,  7,  9,  6, 12],
#        [ 7, 17,  7,  3,  9]])

# %%
matriz.max(1)
matriz.max(0)
# Out:
# array([ 8, 17,  9,  6, 12])

# %% [markdown]
# ### Argmax

# %%
arr.argmax()
# Out:
# 6

# %%
matriz.argmax(0)
# Out:
# array([0, 1, 0, 0, 0])

# %% [markdown]
# ### Min

# %%
arr.min()
# Out:
# 3

# %%
matriz.min(0)
# Out:
# array([7, 7, 7, 3, 9])

# %% [markdown]
# ### Argmin

# %%
arr.argmin()
# Out:
# 8

# %%
matriz.argmin(1)
# Out:
# array([3, 3])

# %% [markdown]
# ### Ptp

# %%
arr
# Out:
# array([ 8,  7,  9,  6, 12,  7, 17,  7,  3,  9])

# %%
arr.ptp()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb Cell 21' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb#ch0000020?line=0'>1</a> arr.ptp()
#
# AttributeError: 'NoneType' object has no attribute 'ptp'

# %%
matriz
# Out:
# array([[ 8,  7,  9,  6, 12],
#        [ 7, 17,  7,  3,  9]])

# %%
matriz.ptp(0)
# Out:
# array([ 1, 10,  2,  3,  3])

# %%
matriz.ptp(1)
# Out:
# array([ 6, 14])

# %% [markdown]
# ### Sort

# %%
arr.sort()
arr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb Cell 26' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb#ch0000025?line=0'>1</a> arr.sort()
#       <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb#ch0000025?line=1'>2</a> arr
#
# AttributeError: 'NoneType' object has no attribute 'sort'

# %% [markdown]
# ### Percentile

# %%
np.percentile(arr,50)
# Out:
# 7.5

# %%
np.percentile(arr,76)
# Out:
# 9.0

# %% [markdown]
# ### Median

# %%
np.median(arr)
# Out:
# 7.5

# %%
np.median(matriz,1)
# Out:
# array([7., 9.])

# %% [markdown]
# ### Standard Deviation (std)

# %%
np.std(arr)
# Out:
# 3.5846896657869842

# %%
arr
# Out:
# array([ 3,  6,  7,  7,  7,  8,  9,  9, 12, 17])

# %%
np.std(arr) ** 2
# Out:
# 12.850000000000001

# %% [markdown]
# ### Variance (Var)

# %%
np.var(arr)
# Out:
# 12.85

# %% [markdown]
# ### Mean

# %%
np.mean(arr)
# Out:
# 8.5

# %% [markdown]
# ### Concatenate

# %%
a = np.array([[1,2],[3,4]])
b = np.array([5,6])

# %%
np.concatenate((a,b),axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb Cell 43' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb#ch0000042?line=0'>1</a> np.concatenate((a,b),axis=0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
a.ndim
b.ndim
# Out:
# 1

# %%
b = np.expand_dims(b,axis=0)

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b

# %%
np.concatenate((a,b),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb Cell 48' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/NumPy/funciones_principales_numpy_854b63de-c966-429f-86b5-7f1427eff9cc.ipynb#ch0000042?line=0'>1</a> np.concatenate((a,b),axis=1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %%
np.concatenate((a,b.T),axis=1)
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])

# %% [markdown]
# ### Transpuesta

# %%
b.T
# Out:
# array([[[5]],
#
#        [[6]]])
