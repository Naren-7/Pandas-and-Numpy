# %% [markdown]
# ## Impottando **Pandas**

# %%
import pandas as pd

# %% [markdown]
# ## Formato **CVS**

# %%
df_books = pd.read_csv(r"./Dates/bestsellers-with-categories.csv", sep=',', header=0, names=['Nameee', 'Authorrr', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'] )

# %%
df_books
# Out:
#                                                 Nameee  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                      Authorrr  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.columns
# Out:
# Index(['Nameee', 'Authorrr', 'User Rating', 'Reviews', 'Price', 'Year',
#        'Genre'],
#       dtype='object')

# %%
df_books[:5]
# Out:
#                                               Nameee  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                    Authorrr  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
man
# Out:
# ¿Qué página del manual desea?
# Por ejemplo, pruebe 'man man'.

# %% [markdown]
# ## Formato **JSON**

# %% [markdown]
# - Maneja data **no estructurada**

# %%
df_json = pd.read_json(r'./Dates/hpcharactersdataraw.json', typ='Series')

# %%
df_json.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1940 entries, 0 to 1939
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 1940 non-null   object
# dtypes: object(1)
# memory usage: 15.3+ KB

# %% [markdown]
# ## Mis propios **DataFrames**

# %%
pd.read_csv("./Dates/Mundo/archive/pakistan_population.csv", delimiter=",")
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0   2020   220892340             2.00        4327022         -233379
# 1   2019   216565318             2.04        4337032         -233379
# 2   2018   212228286             2.08        4322077         -233379
# 3   2017   207906209             2.10        4274856         -233379
# 4   2016   203631353             2.11        4204389         -233379
# 5   2015   199426964             2.14        4000465         -215833
# 6   2010   179424641             2.28        3824127          -67961
# 7   2005   160304008             2.41        3592086         -130036
# 8   2000   142343578             2.83        3713348           94182
# 9   1995   123776839             2.83        3225784         -204677
# 10  1990   107647921             3.15        3091282           27958
# 11  1985    92191510             3.39        2827433          277424
# 12  1980    78054343             3.16        2247493          134441
# ...

# %%
#df = pd.read_json("https://static.platzi.com/media/public/uploads/hpcharactersdataraw_3d934e85-dfa4-42ec-8520-fadfbecae574.json")

# %% [markdown]
# ## Inforamacion **resumida** de una tabla con **pandas**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1940 entries, 0 to 1939
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1940 non-null   object
#  1   Link          1940 non-null   object
#  2   Descr         1940 non-null   object
#  3   Gender        1940 non-null   object
#  4   Species/Race  1940 non-null   object
#  5   Blood         1940 non-null   object
#  6   School        1940 non-null   object
#  7   Profession    1940 non-null   object
# dtypes: object(8)
# memory usage: 121.4+ KB
