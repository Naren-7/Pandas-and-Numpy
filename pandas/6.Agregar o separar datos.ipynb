# %% [markdown]
# ## Importando **Pandas**

# %%
import pandas as pd
import numpy as np

# %%
df_books = pd.read_csv(r"./Dates/bestsellers-with-categories.csv", sep=',', header=0)

# %%
df_books.head(2) # Prmeras filas o las que les indiques.

# df_books.tail(4) # lo mismo pero con las ultumas
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ## **Drop** columns

# %% [markdown]
# - Usa el atributo **inplace** cuando no definas el **DataFrames**

# %%
df_books.drop('Genre', axis=1,inplace=True)

# %%
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year
# 0    17350      8  2016
# 1     2052     22  2011
# 2    18979     15  2018

# %% [markdown]
# #### Definiedo en una variable :)

# %%
df_books = df_books.drop('Year', axis=1)

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %% [markdown]
# ### Otra manera de borrar no recomendada

# %%
del df_books['Price']

# %% [markdown]
# ## Drop **Rows**

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350
# 1              11/22/63: A Novel  Stephen King          4.6     2052

# %%
df_books.drop(0,axis=0, inplace=True)

# %%
df_books.head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews
# 1     2052
# 2    18979

# %%
df_books.drop([1, 3, 2],axis=0).head(2)
# Out:
#                                                 Name  \
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews
# 4  National Geographic Kids          4.8     7665
# 5       George R. R. Martin          4.4    12643

# %%
df_books.drop(range(0,10),axis=0).head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/pandas/Agregar o separar datos.ipynb Cell 20' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/pandas/Agregar%20o%20separar%20datos.ipynb#ch0000019?line=0'>1</a> df_books.drop(range(0,10),axis=0).head(2)
#
# File ~/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/naren/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///home/naren/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %% [markdown]
# ## Add Columns

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre  Nueva columna  Calidad  Rango
# 0  2016  Non Fiction              2        2      0
# 1  2011      Fiction              2        2      1

# %%
df_books['xx '] = np.arange(0, df_books.shape[0]) # Valor no numerico
df_books
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  xx
# 1                Stephen King          4.6     2052    0
# 2          Jordan B. Peterson          4.7    18979    1
# 3               George Orwell          4.7    21424    2
# 4    National Geographic Kids          4.8     7665    3
# ...

# %%
df_books.drop('xx',axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/naren/Documentos/Manipulacion con Pandas Y NumPy/pandas/Agregar o separar datos.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/naren/Documentos/Manipulacion%20con%20Pandas%20Y%20NumPy/pandas/Agregar%20o%20separar%20datos.ipynb#ch0000036?line=0'>1</a> df_books.drop('xx',axis=1, inplace=True)
#
# File ~/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/naren/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///home/naren/anaconda3/envs/numpy/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %%
df_books.head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  xx
# 1     2052    0
# 2    18979    1

# %%
df_books.shape[0] # Hace referencia a las filas
# Out:
# 550

# %%
data = np.arange(0, df_books.shape[0])

# %%
df_books['Rango'] =  data

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Add **Rows**

# %% [markdown]
# - Hay **muchos** más **metodos** para agregar, este consume **menos recursos**.

# %%
df_books = df_books.append(df_books)
# Out:
# /tmp/ipykernel_95070/1617886562.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books = df_books.append(df_books)

# %%
df_books.shape[0]
# Out:
# 1100

# %%
df_books.drop_duplicates() # Elimina duplicados
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#df_books.append({'Name':'Cien años de Soledad', 'Author':'Gabriel García Márquez', "User Rating": 4.8, 'Reviews':20000,'Year':1967, 'Price':25}, ignore_index = True)
df_books.append({'Name': 'Cunumi te lo meto', 'Author': 'Fara love¿', 'User Rating': 4.5, 'Reviews':2999922292, 'Year':2021, 'Price':13}, ignore_index=True)
# Out:
# /tmp/ipykernel_95070/1862842556.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books.append({'Name': 'Cunumi te lo meto', 'Author': 'Fara love¿', 'User Rating': 4.5, 'Reviews':2999922292, 'Year':2021, 'Price':13}, ignore_index=True)
#                                                    Name  \
# 0                         10-Day Green Smoothie Cleanse
# 1                                     11/22/63: A Novel
# 2               12 Rules for Life: An Antidote to Chaos
# 3                                1984 (Signet Classics)
# 4     5,000 Awesome Facts (About Everything!) (Natio...
# ...                                                 ...
# 1096  You Are a Badass: How to Stop Doubting Your Gr...
# 1097  You Are a Badass: How to Stop Doubting Your Gr...
# 1098  You Are a Badass: How to Stop Doubting Your Gr...
# 1099  You Are a Badass: How to Stop Doubting Your Gr...
# ...

# %%
date = {'El ultimo curso', 'naren', 4.8, 3333, 2018, 32 }

# %%
df_books.append(date, ignore_index=True)
# Out:
# /tmp/ipykernel_12106/245816920.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_books.append(date, ignore_index=True)
#                                                   Name  \
# 0                                    11/22/63: A Novel
# 1              12 Rules for Life: An Antidote to Chaos
# 2                               1984 (Signet Classics)
# 3    5,000 Awesome Facts (About Everything!) (Natio...
# 4        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 545  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549                                    El ultimo curso
#
#                        Author  User Rating  Reviews    xx  Athour
# ...

# %%
df_books.tail(2)
# Out:
#                                                   Name       Author  \
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  xx
# 548          4.7    14331  547
# 549          4.7    14331  548
